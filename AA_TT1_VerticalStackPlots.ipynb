# %% [markdown]
# # Simple plot experimental data of TT-1
# Initially developed by Apiwat
#
# * Plot the graph in a single column, with multiple rows

# %%
import numpy as np
import matplotlib.pyplot as plt
from icecream import ic
import pandas as pd
from cycler import cycler

from TT1_Experiment_Analysis_Module import *

# %% [markdown]
# ## Inputs

# %%
OutputHome = './Discharges'
DischargeNo1 = 2179          # number only
DischargeNo2 = 2183          # number only
DischargeNo3 = 2198          # number only

var_load = ['IP1', 'VP0', 'VP1', 'IOH1', 'GP', 'HCN2', 'HA', 'IT1']
var_plot = ['IP1', 'BT0', 'VP0', 'GP', 'NE2', 'HA']

# %%
Path_output = '%s'%(OutputHome)
print('Path to the output folder: ', Path_output)
# Out:
# Path to the output folder:  ./Discharges

# %% [markdown]
# ## Load the data

# %%
shot1 = TT1Discharge(DischargeNo1, Path_Output=Path_output)
shot2 = TT1Discharge(DischargeNo2, Path_Output=Path_output)
shot3 = TT1Discharge(DischargeNo3, Path_Output=Path_output)
# Out:
# Shot Number: 2179
# Path:  ./Discharges/2179
# Shot Number: 2183
# Path:  ./Discharges/2183
# Shot Number: 2198
# Path:  ./Discharges/2198

# %%
shot1.Read_0D_TN(variable=var_load)
shot2.Read_0D_TN(variable=var_load)
shot3.Read_0D_TN(variable=var_load)
# Out:
# Loading variable:        IP1    Path to data:  ./Discharges/2179/IP1.txt
# Loading variable:        VP0    Path to data:  ./Discharges/2179/VP0.txt
# Loading variable:        VP1    Path to data:  ./Discharges/2179/VP1.txt
# Loading variable:       IOH1    Path to data:  ./Discharges/2179/IOH1.txt
# Loading variable:         GP    Path to data:  ./Discharges/2179/GP.txt
# Loading variable:       HCN2    Path to data:  ./Discharges/2179/HCN2.txt
# Loading variable:         HA    Path to data:  ./Discharges/2179/HA.txt
# Loading variable:        IT1    Path to data:  ./Discharges/2179/IT1.txt
# Loading variable:        IP1    Path to data:  ./Discharges/2183/IP1.txt
# Loading variable:        VP0    Path to data:  ./Discharges/2183/VP0.txt
# Loading variable:        VP1    Path to data:  ./Discharges/2183/VP1.txt
# Loading variable:       IOH1    Path to data:  ./Discharges/2183/IOH1.txt
# Loading variable:         GP    Path to data:  ./Discharges/2183/GP.txt
# Loading variable:       HCN2    Path to data:  ./Discharges/2183/HCN2.txt
# Loading variable:         HA    Path to data:  ./Discharges/2183/HA.txt
# Loading variable:        IT1    Path to data:  ./Discharges/2183/IT1.txt
# Loading variable:        IP1    Path to data:  ./Discharges/2198/IP1.txt
# Loading variable:        VP0    Path to data:  ./Discharges/2198/VP0.txt
# Loading variable:        VP1    Path to data:  ./Discharges/2198/VP1.txt
# Loading variable:       IOH1    Path to data:  ./Discharges/2198/IOH1.txt
# Loading variable:         GP    Path to data:  ./Discharges/2198/GP.txt
# Loading variable:       HCN2    Path to data:  ./Discharges/2198/HCN2.txt
# Loading variable:         HA    Path to data:  ./Discharges/2198/HA.txt
# Loading variable:        IT1    Path to data:  ./Discharges/2198/IT1.txt

# %%
# shot1.exp['IP1']

# %% [markdown]
# # Visualization

# %%
fig = PlotSingleColumn([shot1, shot2, shot3], var=var_plot, tinit=330, tfinal=450, 
                       savefig=False, height=1.4, grid=True, unit=True, 
                       Interpolation=True, InterpolationPeriod=0.5)
# Out:
# Total number of discharges: 3
# 2179, 2183, 2198,
# Total variables to plot: 6
# IP1, BT0, VP0, GP, NE2, HA,
# -----------------------------------------------------------
#                             Summary
# -----------------------------------------------------------
# Shot Number                             , 2179
# Date and time                           , 2023/08/30 16:21:4
# Discharge time [ms]                     , 42.34
# Discharge time (begin) [ms]             , 337.3
# Discharge time (end) [ms]               , 379.6
# Bt0 (max, average > 95%) [T]            , 1.084
# Ip (max, average > 95%) [kA]            , 46.21
# Ne (max, average > 95%) [m**-3]         , 1.221e+19
# Ne (average) [m**-3]                    , 7.992e+18
# -----------------------------------------------------------
#                             Summary
# -----------------------------------------------------------
# Shot Number                             , 2183
# Date and time                           , 2023/08/30 17:03:1
# Discharge time [ms]                     , 60.44
# Discharge time (begin) [ms]             , 337.4
# Discharge time (end) [ms]               , 397.8
# Bt0 (max, average > 95%) [T]            , 1.08
# Ip (max, average > 95%) [kA]            , 50.29
# Ne (max, average > 95%) [m**-3]         , 1.168e+19
# Ne (average) [m**-3]                    , 6.934e+18
# -----------------------------------------------------------
#                             Summary
# -----------------------------------------------------------
# Shot Number                             , 2198
# Date and time                           , 2023/08/31 14:16:5
# Discharge time [ms]                     , 82.98
# Discharge time (begin) [ms]             , 337.7
# Discharge time (end) [ms]               , 420.7
# Bt0 (max, average > 95%) [T]            , 1.076
# Ip (max, average > 95%) [kA]            , 49.85
# Ne (max, average > 95%) [m**-3]         , 1.157e+19
# Ne (average) [m**-3]                    , 8.224e+18

# %%
# shot1.Print_DischargeSummary(OutputMode=1)
