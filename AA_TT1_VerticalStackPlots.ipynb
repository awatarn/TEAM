# %% [markdown]
# # Simple plot experimental data of TT-1
# Initially developed by Apiwat
#
# * Plot the graph in a single column, with multiple rows

# %%
import numpy as np
import matplotlib.pyplot as plt
from icecream import ic
import pandas as pd
from cycler import cycler

from TT1_Experiment_Analysis_Module import *

# %% [markdown]
# ## Inputs

# %%
OutputHome = './Discharges'
DischargeNo1 = 2178          # number only
DischargeNo2 = 2186          # number only
DischargeNo3 = 2196          # number only

var_load = ['IP1', 'VP0', 'VP1', 'IOH1', 'GP', 'HCN2', 'HA', 'IT1']
var_plot = ['IP1', 'BT0', 'VP0', 'GP', 'NE2', 'HA']

# %%
Path_output = '%s'%(OutputHome)
print('Path to the output folder: ', Path_output)
# Out:
# Path to the output folder:  ./Discharges

# %% [markdown]
# ## Load the data

# %%
shot1 = TT1Discharge(DischargeNo1, Path_Output=Path_output)
shot2 = TT1Discharge(DischargeNo2, Path_Output=Path_output)
shot3 = TT1Discharge(DischargeNo3, Path_Output=Path_output)
# Out:
# Shot Number: 2178
# Path:  ./Discharges/2178
# Shot Number: 2186
# Path:  ./Discharges/2186
# Shot Number: 2196
# Path:  ./Discharges/2196

# %%
shot1.Read_0D_TN(variable=var_load)
shot2.Read_0D_TN(variable=var_load)
shot3.Read_0D_TN(variable=var_load)
# Out:
# Loading variable:        IP1    Path to data:  ./Discharges/2178/IP1.txt
# Loading variable:        VP0    Path to data:  ./Discharges/2178/VP0.txt
# Loading variable:        VP1    Path to data:  ./Discharges/2178/VP1.txt
# Loading variable:       IOH1    Path to data:  ./Discharges/2178/IOH1.txt
# Loading variable:         GP    Path to data:  ./Discharges/2178/GP.txt
# Loading variable:       HCN2    Path to data:  ./Discharges/2178/HCN2.txt
# Loading variable:         HA    Path to data:  ./Discharges/2178/HA.txt
# Loading variable:        IT1    Path to data:  ./Discharges/2178/IT1.txt
# Loading variable:        IP1    Path to data:  ./Discharges/2186/IP1.txt
# Loading variable:        VP0    Path to data:  ./Discharges/2186/VP0.txt
# Loading variable:        VP1    Path to data:  ./Discharges/2186/VP1.txt
# Loading variable:       IOH1    Path to data:  ./Discharges/2186/IOH1.txt
# Loading variable:         GP    Path to data:  ./Discharges/2186/GP.txt
# Loading variable:       HCN2    Path to data:  ./Discharges/2186/HCN2.txt
# Loading variable:         HA    Path to data:  ./Discharges/2186/HA.txt
# Loading variable:        IT1    Path to data:  ./Discharges/2186/IT1.txt
# Loading variable:        IP1    Path to data:  ./Discharges/2196/IP1.txt
# Loading variable:        VP0    Path to data:  ./Discharges/2196/VP0.txt
# Loading variable:        VP1    Path to data:  ./Discharges/2196/VP1.txt
# Loading variable:       IOH1    Path to data:  ./Discharges/2196/IOH1.txt
# Loading variable:         GP    Path to data:  ./Discharges/2196/GP.txt
# Loading variable:       HCN2    Path to data:  ./Discharges/2196/HCN2.txt
# Loading variable:         HA    Path to data:  ./Discharges/2196/HA.txt
# Loading variable:        IT1    Path to data:  ./Discharges/2196/IT1.txt

# %%
# shot1.exp['IP1']

# %% [markdown]
# # Visualization

# %%
fig = PlotSingleColumn([shot1, shot2, shot3], var=var_plot, tinit=330, tfinal=450, 
                       savefig=False, height=1.4, grid=True, unit=True, 
                       Interpolation=True, InterpolationPeriod=0.5)
# Out:
# Total number of discharges: 3
# 2178, 2186, 2196,
# Total variables to plot: 6
# IP1, BT0, VP0, GP, NE2, HA,
# -----------------------------------------------------------
#                             Summary
# -----------------------------------------------------------
# Shot Number                             , 2178
# Date and time                           , 2023/08/30 16:11:4
# Discharge time [ms]                     , 44.92
# Discharge time (begin) [ms]             , 337.1
# Discharge time (end) [ms]               , 382.0
# Bt0 (max, average > 95%) [T]            , 1.085
# Ip (max, average > 95%) [kA]            , 48.51
# Ne (max, average > 95%) [m**-3]         , 1.463e+19
# Ne (average) [m**-3]                    , 9.637e+18
# -----------------------------------------------------------
#                             Summary
# -----------------------------------------------------------
# Shot Number                             , 2186
# Date and time                           , 2023/08/30 17:35:2
# Discharge time [ms]                     , 104.1
# Discharge time (begin) [ms]             , 337.4
# Discharge time (end) [ms]               , 441.5
# Bt0 (max, average > 95%) [T]            , 1.075
# Ip (max, average > 95%) [kA]            , 51.05
# Ne (max, average > 95%) [m**-3]         , 1.281e+19
# Ne (average) [m**-3]                    , 8.87e+18
# -----------------------------------------------------------
#                             Summary
# -----------------------------------------------------------
# Shot Number                             , 2196
# Date and time                           , 2023/08/31 13:55:0
# Discharge time [ms]                     , 78.62
# Discharge time (begin) [ms]             , 337.9
# Discharge time (end) [ms]               , 416.5
# Bt0 (max, average > 95%) [T]            , 1.081
# Ip (max, average > 95%) [kA]            , 50.16
# Ne (max, average > 95%) [m**-3]         , 7.146e+18
# Ne (average) [m**-3]                    , 6.792e+18

# %%
# shot1.Print_DischargeSummary(OutputMode=1)
